# %% [markdown]
# # Visualización de Reglas de Asociación Difusas

# %%
from fuzzy_visualization import load_graph_from_json, plot_graph

# %%
G = load_graph_from_json("fuzzy_rules_graph.json")
plot_graph(G)
